# %%
from corners_drawing_plots import drawing_plots

drawing_plots = drawing_plots()
drawing_plots.draw_plots()
# Out:
# ['C:\\Users\\Ростислав\\Documents\\vscode projects\\Test Python\\plots\\gt_corners',
#  'C:\\Users\\Ростислав\\Documents\\vscode projects\\Test Python\\plots\\rb_corners',
#  'C:\\Users\\Ростислав\\Documents\\vscode projects\\Test Python\\plots\\mean',
#  'C:\\Users\\Ростислав\\Documents\\vscode projects\\Test Python\\plots\\max',
#  'C:\\Users\\Ростислав\\Documents\\vscode projects\\Test Python\\plots\\min',
#  'C:\\Users\\Ростислав\\Documents\\vscode projects\\Test Python\\plots\\floor_mean',
#  'C:\\Users\\Ростислав\\Documents\\vscode projects\\Test Python\\plots\\floor_max',
#  'C:\\Users\\Ростислав\\Documents\\vscode projects\\Test Python\\plots\\floor_min',
#  'C:\\Users\\Ростислав\\Documents\\vscode projects\\Test Python\\plots\\ceiling_mean',
#  'C:\\Users\\Ростислав\\Documents\\vscode projects\\Test Python\\plots\\ceiling_max',
#  'C:\\Users\\Ростислав\\Documents\\vscode projects\\Test Python\\plots\\ceiling_min']

# %%
drawing_plots.describe()
# Out:
#         gt_corners   rb_corners         mean          max          min  \
# count  1347.000000  1347.000000  1347.000000  1347.000000  1347.000000
# mean      4.307350     4.307350    12.895320    25.448011     2.920388
# std       0.814412     0.814412    21.839948    42.758159     9.258972
# min       4.000000     4.000000     0.192973     0.323886     0.007456
# 25%       4.000000     4.000000     0.658488     1.243804     0.147432
# 50%       4.000000     4.000000     2.123456     4.703514     0.279876
# 75%       4.000000     4.000000    14.810982    28.312051     0.674444
# max      10.000000    10.000000   121.301055   179.165483    81.764483
#
#         floor_mean    floor_max    floor_min  ceiling_mean  ceiling_max  \
# count  1347.000000  1347.000000  1347.000000   1347.000000  1347.000000
# mean     11.022443    20.405499     3.146246     14.768198    24.848020
# std      19.136320    33.189081     9.559611     26.047057    42.345579
# ...
